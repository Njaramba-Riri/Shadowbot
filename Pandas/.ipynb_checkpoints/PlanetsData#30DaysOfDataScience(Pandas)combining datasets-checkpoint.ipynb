# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
planets=sns.load_dataset('planets')
planets.shape
# Out:
# (1035, 6)

# %%
planets.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
planets.groupby('method')['year'].describe()
# Out:
#                                count         mean       std     min      25%  \
# method
# Astrometry                       2.0  2011.500000  2.121320  2010.0  2010.75
# Eclipse Timing Variations        9.0  2010.000000  1.414214  2008.0  2009.00
# Imaging                         38.0  2009.131579  2.781901  2004.0  2008.00
# Microlensing                    23.0  2009.782609  2.859697  2004.0  2008.00
# Orbital Brightness Modulation    3.0  2011.666667  1.154701  2011.0  2011.00
# Pulsar Timing                    5.0  1998.400000  8.384510  1992.0  1992.00
# Pulsation Timing Variations      1.0  2007.000000       NaN  2007.0  2007.00
# Radial Velocity                553.0  2007.518987  4.249052  1989.0  2005.00
# Transit                        397.0  2011.236776  2.077867  2002.0  2010.00
# Transit Timing Variations        4.0  2012.500000  1.290994  2011.0  2011.75
#
#                                   50%      75%     max
# method
# ...

# %% [markdown]
# import matplotlib.pyplot as plt
# %matplotlib inline
# planets.pivot_table('method', index='method', columns=''.plot()
# plt.legend()

# %%
#Aggregation in pandas
rng=np.random.RandomState(42)
ser=pd.Series(rng.rand(5))
ser
# Out:
# 0    0.374540
# 1    0.950714
# 2    0.731994
# 3    0.598658
# 4    0.156019
# dtype: float64

# %%
ser.sum()
# Out:
# 2.811925491708157

# %%
ser.min()
# Out:
# 0.15601864044243652

# %%
df=pd.DataFrame({'A':rng.rand(5),
                'B':rng.rand(5)})
df
# Out:
#           A         B
# 0  0.155995  0.020584
# 1  0.058084  0.969910
# 2  0.866176  0.832443
# 3  0.601115  0.212339
# 4  0.708073  0.181825

# %%
df.mean()
# Out:
# A    0.477888
# B    0.443420
# dtype: float64

# %%
df.mean(axis='columns')
# Out:
# 0    0.088290
# 1    0.513997
# 2    0.849309
# 3    0.406727
# 4    0.444949
# dtype: float64

# %%
df.dropna().describe()
# Out:
#               A         B
# count  5.000000  5.000000
# mean   0.477888  0.443420
# std    0.353125  0.426952
# min    0.058084  0.020584
# 25%    0.155995  0.181825
# 50%    0.601115  0.212339
# 75%    0.708073  0.832443
# max    0.866176  0.969910

# %%
df.mad()
# Out:
# A    0.296679
# B    0.366205
# dtype: float64

# %%
df.prod()
# Out:
# A    0.003340
# B    0.000642
# dtype: float64

# %%
#GroupBy:Split,Apply, Combine
dd=pd.DataFrame({'key':['A','B','C','A','C','B'],
                'data':range(6)},
               columns=['key','data'])
dd
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   C     4
# 5   B     5

# %%
dd.groupby('key').describe()
# Out:
#      data
#     count mean       std  min   25%  50%   75%  max
# key
# A     2.0  1.5  2.121320  0.0  0.75  1.5  2.25  3.0
# B     2.0  3.0  2.828427  1.0  2.00  3.0  4.00  5.0
# C     2.0  3.0  1.414214  2.0  2.50  3.0  3.50  4.0

# %%
dd.groupby('key').prod()
# Out:
#      data
# key
# A       0
# B       5
# C       8

# %%
#GroupBy object
df=pd.read_csv('~/downloads/2021-alldata.csv')

# %%
df.groupby('NAME')

# %%
df.groupby('NAME')['ESTIMATESBASE2020']

# %%
df.groupby('NAME')['ESTIMATESBASE2020'].median()
# Out:
# NAME
# Alabama                   5024279.0
# Alaska                     733391.0
# Arizona                   7151502.0
# Arkansas                  3011524.0
# California               39538223.0
# Colorado                  5773714.0
# Connecticut               3605944.0
# Delaware                   989948.0
# District of Columbia       689545.0
# Florida                  21538187.0
# Georgia                  10711908.0
# Hawaii                    1455271.0
# Idaho                     1839106.0
# Illinois                 12812508.0
# Indiana                   6785528.0
# Iowa                      3190369.0
# Kansas                    2937880.0
# Kentucky                  4505836.0
# Louisiana                 4657757.0
# Maine                     1362359.0
# Maryland                  6177224.0
# Massachusetts             7029917.0
# Michigan                 10077331.0
# Midwest Region           68985454.0
# Minnesota                 5706494.0
# Mississippi               2961279.0
# ...

# %%
df.head(15)
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  ESTIMATESBASE2020  \
# 0       10      0        0      0         United States          331449281
# 1       20      1        0      0      Northeast Region           57609148
# 2       20      2        0      0        Midwest Region           68985454
# 3       20      3        0      0          South Region          126266107
# 4       20      4        0      0           West Region           78588572
# 5       40      3        6      1               Alabama            5024279
# 6       40      4        9      2                Alaska             733391
# 7       40      4        8      4               Arizona            7151502
# 8       40      3        7      5              Arkansas            3011524
# 9       40      4        9      6            California           39538223
# 10      40      4        8      8              Colorado            5773714
# ...

# %%
df.groupby('REGION')

# %%
df.groupby('REGION')['NAME']

# %%
df.groupby('REGION')['NAME'].describe()
# Out:
#        count unique               top freq
# REGION
# 0          1      1     United States    1
# 1         10     10  Northeast Region    1
# 2         13     13    Midwest Region    1
# 3         18     18      South Region    1
# 4         14     14       West Region    1
# X          1      1       Puerto Rico    1

# %%
df.groupby('DIVISION')['NAME','REGION'].describe()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7852\3408047720.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('DIVISION')['NAME','REGION'].describe()
#           NAME                            REGION
#          count unique            top freq  count unique top freq
# DIVISION
# 0            5      5  United States    1      5      5   0    1
# 1            6      6    Connecticut    1      6      1   1    6
# 2            3      3     New Jersey    1      3      1   1    3
# 3            5      5       Illinois    1      5      1   2    5
# 4            7      7           Iowa    1      7      1   2    7
# 5            9      9       Delaware    1      9      1   3    9
# 6            4      4        Alabama    1      4      1   3    4
# 7            4      4       Arkansas    1      4      1   3    4
# 8            8      8        Arizona    1      8      1   4    8
# ...

# %%
d1=pd.read_csv('~/downloads/student-mat.csv', sep=";")
d2=pd.read_csv('~/downloads/student-por.csv', sep=';')

# %%
d1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
d2
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
d1.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
d2.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
d3=pd.merge(d1,d2, on=(['school', 'sex', 'age', 'address', 'famsize',
'Pstatus', 'Medu', 'Fedu','Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime','failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery','higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
'Walc', 'health']),how='outer', suffixes=['_mat','_por'])
d3
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 3       GP   F   15       U     GT3       T     4     2   health  services
# 4       GP   F   16       U     GT3       T     3     3    other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 877     MS   F   18       R     GT3       T     2     2  at_home     other
# 878     MS   F   17       U     GT3       T     4     3  teacher     other
# 879     MS   F   18       R     GT3       T     4     4  teacher   at_home
# 880     MS   F   18       U     LE3       T     3     1  teacher  services
# 881     MS   F   18       U     GT3       T     1     1    other     other
#
# ...

# %%
d3.isnull().any()
# Out:
# school          False
# sex             False
# age             False
# address         False
# famsize         False
# Pstatus         False
# Medu            False
# Fedu            False
# Mjob            False
# Fjob            False
# reason          False
# guardian        False
# traveltime      False
# studytime       False
# failures        False
# schoolsup       False
# famsup          False
# paid            False
# activities      False
# nursery         False
# higher          False
# internet        False
# romantic        False
# famrel          False
# freetime        False
# goout           False
# Dalc            False
# Walc            False
# health          False
# absences_mat     True
# G1_mat           True
# G2_mat           True
# G3_mat           True
# absences_por     True
# G1_por           True
# G2_por           True
# G3_por           True
# dtype: bool

# %%
d3.fillna(0)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 3       GP   F   15       U     GT3       T     4     2   health  services
# 4       GP   F   16       U     GT3       T     3     3    other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 877     MS   F   18       R     GT3       T     2     2  at_home     other
# 878     MS   F   17       U     GT3       T     4     3  teacher     other
# 879     MS   F   18       R     GT3       T     4     4  teacher   at_home
# 880     MS   F   18       U     LE3       T     3     1  teacher  services
# 881     MS   F   18       U     GT3       T     1     1    other     other
#
# ...

# %%
#column indexing
d3.groupby('school')['Pstatus'].describe()
# Out:
#        count unique top freq
# school
# GP       630      2   T  553
# MS       252      2   T  225

# %%
#iteration over groups
for(school,group) in d3.groupby('school'):
    print("{0:30s} shape={1}".format(school,group.shape))
# Out:
# GP                             shape=(630, 37)
# MS                             shape=(252, 37)

# %%
#Dispatch methods
d3.groupby('Mjob')['school'].describe().unstack()
# Out:
#         Mjob
# count   at_home     168
#         health       69
#         other       334
#         services    204
#         teacher     107
# unique  at_home       2
#         health        2
#         other         2
#         services      2
#         teacher       2
# top     at_home      GP
#         health       GP
#         other        GP
#         services     GP
#         teacher      GP
# freq    at_home      88
#         health       56
#         other       230
#         services    169
#         teacher      87
# dtype: object

# %%
#aggregate,filer,transform,apply
rng=np.random.RandomState(0)
df=pd.DataFrame({'key':['A','B','C','D','A','B','C','D'],
                'data1':range(8),
                'data2':rng.randint(0,10,8)},
               columns=['key','data1','data2'])
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   D      3      3
# 4   A      4      7
# 5   B      5      9
# 6   C      6      3
# 7   D      7      5

# %%
#aggregation
df.groupby('key').aggregate(['min','sum', np.median, max])
# Out:
#     data1                data2
#       min sum median max   min sum median max
# key
# A       0   4    2.0   4     5  12    6.0   7
# B       1   6    3.0   5     0   9    4.5   9
# C       2   8    4.0   6     3   6    3.0   3
# D       3  10    5.0   7     3   8    4.0   5

# %%
df.groupby('key').aggregate({'data1':'min',
                            'data2':'max'})
# Out:
#      data1  data2
# key
# A        0      7
# B        1      9
# C        2      3
# D        3      5

# %%
#filtering
def filter_func(x):
    return x['data2'].std()>4

print(df); print(df.groupby('key').std());
print(df.groupby('key').filter(filter_func))
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   D      3      3
# 4   A      4      7
# 5   B      5      9
# 6   C      6      3
# 7   D      7      5
#         data1     data2
# key
# A    2.828427  1.414214
# B    2.828427  6.363961
# C    2.828427  0.000000
# D    2.828427  1.414214
#   key  data1  data2
# 1   B      1      0
# 5   B      5      9

# %%
#Transformation
df.groupby('key').transform(lambda x:x-x.mean())
# Out:
#    data1  data2
# 0   -2.0   -1.0
# 1   -2.0   -4.5
# 2   -2.0    0.0
# 3   -2.0   -1.0
# 4    2.0    1.0
# 5    2.0    4.5
# 6    2.0    0.0
# 7    2.0    1.0

# %%
#apply()method
def norm_by_data2(x):
    #x is a DF of group values
    x['data1'] /=x['data2'].sum()
    return x

print(df); print(df.groupby('key').apply(norm_by_data2))
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   D      3      3
# 4   A      4      7
# 5   B      5      9
# 6   C      6      3
# 7   D      7      5
#   key     data1  data2
# 0   A  0.000000      5
# 1   B  0.111111      0
# 2   C  0.333333      3
# 3   D  0.375000      3
# 4   A  0.333333      7
# 5   B  0.555556      9
# 6   C  1.000000      3
# 7   D  0.875000      5

# %%
#specifying the split key
L = [0, 1, 0, 1, 2, 0]
print(df); print(df.groupby(L).sum())
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   D      3      3
# 4   A      4      7
# 5   B      5      9
# 6   C      6      3
# 7   D      7      5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7852\1843545499.py in <module>
#       1 #specifying the split key
#       2 L = [0, 1, 0, 1, 2, 0]
# ----> 3 print(df); print(df.groupby(L).sum())
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7719         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720         # "Union[bool, NoDefault]"; expected "bool"
# -> 7721         return DataFrameGroupBy(
#    7722             obj=self,
#    7723             keys=by,
#
# ...

# %%
print(df); print(df.groupby(df['key']).sum())
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   D      3      3
# 4   A      4      7
# 5   B      5      9
# 6   C      6      3
# 7   D      7      5
#      data1  data2
# key
# A        4     12
# B        6      9
# C        8      6
# D       10      8

# %%
df2=df.set_index('key')
mapping={'A':'vowel','B':'consonant', 'C':'consonant'}

print(df2); print(df2.groupby(mapping).sum())
# Out:
#      data1  data2
# key
# A        0      5
# B        1      0
# C        2      3
# D        3      3
# A        4      7
# B        5      9
# C        6      3
# D        7      5
#            data1  data2
# key
# consonant     14     15
# vowel          4     12

# %%
#passing any python func
print(df2); print(df2.groupby(str.lower).mean())
# Out:
#      data1  data2
# key
# A        0      5
# B        1      0
# C        2      3
# D        3      3
# A        4      7
# B        5      9
# C        6      3
# D        7      5
#      data1  data2
# key
# a      2.0    6.0
# b      3.0    4.5
# c      4.0    3.0
# d      5.0    4.0

# %%
df2.groupby([str.lower, mapping]).mean()
# Out:
#                data1  data2
# key key
# a   vowel        2.0    6.0
# b   consonant    3.0    4.5
# c   consonant    4.0    3.0

# %%
df2
# Out:
#      data1  data2
# key
# A        0      5
# B        1      0
# C        2      3
# D        3      3
# A        4      7
# B        5      9
# C        6      3
# D        7      5

# %%
#Grouping
decade=10*(d3['age']//10)
decade=decade.astype(str)+ 's'
decade.name='age'
d3.groupby(['school',decade])['absences_mat'].sum().unstack().fillna(0).plot()
# Out:
# <AxesSubplot:xlabel='school'>

# %%
d3.groupby(['school','address'])['age'].describe().unstack()
# Out:
#          count              mean                  std             min        \
# address      R      U          R          U         R         U     R     U
# school
# GP       115.0  515.0  16.800000  16.642718  1.312557  1.230498  15.0  15.0
# MS       132.0  120.0  16.878788  17.183333  1.217119  1.173828  15.0  15.0
#
#           25%         50%         75%         max
# address     R     U     R     U     R     U     R     U
# school
# GP       16.0  16.0  17.0  17.0  18.0  18.0  21.0  22.0
# MS       16.0  16.0  17.0  17.0  18.0  18.0  21.0  20.0

# %%
d3
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 3       GP   F   15       U     GT3       T     4     2   health  services
# 4       GP   F   16       U     GT3       T     3     3    other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 877     MS   F   18       R     GT3       T     2     2  at_home     other
# 878     MS   F   17       U     GT3       T     4     3  teacher     other
# 879     MS   F   18       R     GT3       T     4     4  teacher   at_home
# 880     MS   F   18       U     LE3       T     3     1  teacher  services
# 881     MS   F   18       U     GT3       T     1     1    other     other
#
# ...

# %%
d3.pivot_table(['age'],index='traveltime',columns=['address'])
# Out:
#                   age
# address             R          U
# traveltime
# 1           16.809524  16.673563
# 2           16.880734  16.958580
# 3           17.000000  16.608696
# 4           16.166667  16.500000

# %%
finance=pd.read_csv('~/downloads/finance.csv')

# %%
import matplotlib.pyplot as plt
finance.pivot_table(['household_size'], index='Respondent Age',aggfunc='mean').plot()
plt.ylabel('Household Size')
plt.grind=True
