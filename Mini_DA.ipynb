# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("~/downloads/finance.csv")

# %%
df.tail(100)
# Out:
#        Unnamed: 0 country                           year Has a Bank account  \
# 22803       23416  Uganda  1970-01-01 00:00:00.000002018                 No
# 22804       23417  Uganda  1970-01-01 00:00:00.000002018                 No
# 22805       23418  Uganda  1970-01-01 00:00:00.000002018                 No
# 22806       23419  Uganda  1970-01-01 00:00:00.000002018                 No
# 22807       23420  Uganda  1970-01-01 00:00:00.000002018                 No
# ...           ...     ...                            ...                ...
# 22898       23518  Uganda  1970-01-01 00:00:00.000002018                 No
# 22899       23519  Uganda  1970-01-01 00:00:00.000002018                 No
# 22900       23520  Uganda  1970-01-01 00:00:00.000002018                 No
# 22901       23521  Uganda  1970-01-01 00:00:00.000002018                 No
# 22902       23522  Uganda  1970-01-01 00:00:00.000002018                 No
#
#       Type of Location Cell Phone Access  household_size  Respondent Age  \
# 22803            Rural                No             4.0            23.0
# 22804            Urban               Yes             3.0            23.0
# 22805            Rural               Yes             7.0            29.0
# 22806            Urban               Yes             4.0            22.0
# 22807            Rural               Yes             7.0            46.0
# ...                ...               ...             ...             ...
# 22898            Rural               Yes             NaN            20.0
# 22899            Rural               Yes             4.0            48.0
# 22900            Rural               Yes             2.0            27.0
# 22901            Rural               Yes             5.0            27.0
# 22902            Urban               Yes             7.0            30.0
#
#       gender_of_respondent The relathip with head           marital_status  \
# 22803                 Male      Head of Household  Married/Living together
# 22804                 Male    Other non-relatives     Single/Never Married
# 22805               Female                 Spouse  Married/Living together
# 22806               Female                 Parent     Single/Never Married
# 22807                 Male      Head of Household  Married/Living together
# ...                    ...                    ...                      ...
# 22898               Female                  Child     Single/Never Married
# 22899               Female      Head of Household       Divorced/Seperated
# 22900               Female      Head of Household     Single/Never Married
# 22901               Female                 Parent                  Widowed
# 22902               Female                 Parent       Divorced/Seperated
#
#        Level of Educuation                Type of Job
# 22803    Primary education              Self employed
# 22804  Secondary education  Formally employed Private
# 22805    Primary education              Self employed
# 22806  Secondary education                  No Income
# 22807    Primary education              Self employed
# ...                    ...                        ...
# 22898    Primary education                  No Income
# 22899  No formal education               Other Income
# 22900  Secondary education               Other Income
# 22901    Primary education               Other Income
# 22902  Secondary education              Self employed
#
# [100 rows x 13 columns]

# %%
df.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c61f0c8f89b5> in <module>
# ----> 1 df.mean()
#
# NameError: name 'df' is not defined

# %%
df.median()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6d467abf240d> in <module>
# ----> 1 df.median()
#
# NameError: name 'df' is not defined

# %%
x=(df["Respondent Age"])
plt.hist(x,100,density=True, facecolor="green")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c3c8e05c07d6> in <module>
# ----> 1 x=(df["Respondent Age"])
#       2 plt.hist(x,100,density=True, facecolor="green")
#       3 plt.show()
#
# NameError: name 'df' is not defined
