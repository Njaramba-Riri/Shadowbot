# %%
import pandas as pd

# %%
data=pd.read_csv('~/downloads/student-mat.csv')

# %%
print(data[index])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 print(data[index])
#
# NameError: name 'index' is not defined

# %%
import numpy as np
age=np.array(data['age'])
print(age)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-438ec639bf9e> in <module>
#       1 import numpy as np
# ...

# %%
data.head(10)
# Out:
#   school;sex;age;address;famsize;Pstatus;Medu;Fedu;Mjob;Fjob;reason;guardian;traveltime;studytime;failures;schoolsup;famsup;paid;activities;nursery;higher;internet;romantic;famrel;freetime;goout;Dalc;Walc;health;absences;G1;G2;G3
# 0  GP;"F";18;"U";"GT3";"A";4;4;"at_home";"teacher...
# 1  GP;"F";17;"U";"GT3";"T";1;1;"at_home";"other";...
# 2  GP;"F";15;"U";"LE3";"T";1;1;"at_home";"other";...
# 3  GP;"F";15;"U";"GT3";"T";4;2;"health";"services...
# 4  GP;"F";16;"U";"GT3";"T";3;3;"other";"other";"h...
# 5  GP;"M";16;"U";"LE3";"T";4;3;"services";"other"...
# 6  GP;"M";16;"U";"LE3";"T";2;2;"other";"other";"h...
# 7  GP;"F";17;"U";"GT3";"A";4;4;"other";"teacher";...
# 8  GP;"M";15;"U";"LE3";"A";3;2;"services";"other"...
# 9  GP;"M";15;"U";"GT3";"T";3;4;"other";"other";"h...

# %%
df=pd.read_csv('~/downloads/finance.csv')

# %%
df.head(15)
# Out:
#     id country     year Has a Bank account Type of Location Cell Phone Access  \
# 0    0   Kenya  00:00.0                Yes            Rural               Yes
# 1    1   Kenya  00:00.0                 No            Rural                No
# 2    2   Kenya  00:00.0                Yes            Urban               Yes
# 3    3   Kenya  00:00.0                 No            Rural               Yes
# 4    4   Kenya  00:00.0                 No            Urban                No
# 5    5   Kenya  00:00.0                 No            Rural                No
# 6    6   Kenya  00:00.0                 No            Rural               Yes
# 7    7   Kenya  00:00.0                 No            Rural               Yes
# 8    8   Kenya  00:00.0                Yes            Rural               Yes
# 9    9   Kenya  00:00.0                 No            Urban               Yes
# 10  10   Kenya  00:00.0                 No            Rural               Yes
# ...

# %%
age=np.array(df['Respondent Age'])
print(age)
# Out:
# [24. 70. 26. ... 27. 27. 30.]

# %%
print("mean age: ",age.mean())
print("Standard deviation: ",age.std())
print("Youngest Person: ",age.min())
print("Oldest person: ",age.max())
# Out:
# mean age:  nan
# Standard deviation:  nan
# Youngest Person:  nan
# Oldest person:  nan

# %%
print("25th percentile: ",np.percentile(age,25))
print("median: ",np.median(age))
print("75th percentile: ",np.percentile(age,75))
# Out:
# 25th percentile:  nan
# median:  nan
# 75th percentile:  nan

# %%
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

# %%
plt.hist(age, facecolor="green")
plt.title("Respondents Age")
plt.xlabel("Age")
plt.ylabel("Respondents")
plt.show()

# %%
df.head(3)
# Out:
#    id country     year Has a Bank account Type of Location Cell Phone Access  \
# 0   0   Kenya  00:00.0                Yes            Rural               Yes
# 1   1   Kenya  00:00.0                 No            Rural                No
# 2   2   Kenya  00:00.0                Yes            Urban               Yes
#
#    household_size  Respondent Age gender_of_respondent The relathip with head  \
# 0             3.0            24.0               Female                 Spouse
# 1             5.0            70.0               Female      Head of Household
# 2             5.0            26.0                 Male         Other relative
#
#             marital_status               Level of Education  \
# 0  Married/Living together              Secondary education
# 1                  Widowed              No formal education
# 2     Single/Never Married  Vocational/Specialised training
#
#             Type of Job
# 0         Self employed
# 1  Government Dependent
# ...

# %%
#comparisons,masks and Boolean logic
account=(df['household_size'])
plt.title("Household Size")
plt.xlabel("No of people per house")
plt.ylabel("Respondents")
plt.hist(account)
plt.show()

# %%
x=np.array(df['household_size'])
x<=3
# Out:
# array([ True, False, False, ...,  True, False, False])

# %%
(2**x)==(x**2)
# Out:
# array([False, False, False, ...,  True, False, False])

# %%
rng=np.random.RandomState(0)
x=rng.randint(10,size=(3,4))

# %%
x
# Out:
# array([[5, 0, 3, 3],
#        [7, 9, 3, 5],
#        [2, 4, 7, 6]])

# %%
x<6
# Out:
# array([[ True,  True,  True,  True],
#        [False, False,  True,  True],
#        [ True,  True, False, False]])

# %%
np.count_nonzero(x<6)
# Out:
# 8

# %%
np.sum(x<6)
# Out:
# 8

# %%
Ho_size1=np.array(np.sum(account<3))

# %%
Ho_size2=np.array(np.sum(account >3))

# %%
Ho_size3=np.array(np.sum(account==3))

# %%
plt.plot(Ho_size1,Ho_size2,Ho_size3)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
np.all(account<3)
# Out:
# False

# %%
np.any(account>8)
# Out:
# True

# %%
np.sum((account>=3)&(account<=2))
# Out:
# 0

# %%
print(account)
# Out:
# 0        3.0
# 1        5.0
# 2        5.0
# 3        5.0
# 4        8.0
#         ...
# 22898    NaN
# 22899    4.0
# 22900    2.0
# 22901    5.0
# 22902    7.0
# Name: household_size, Length: 22903, dtype: float64

# %%
np.sum(~((account<=3)|(account>=1)))
# Out:
# 27

# %%
print("Houses without people: ", np.sum(account == 0))
print("Houses with people: ", np.sum(account != 0))
print("Houses with more than 5 people :", np.sum(account > 5))
print("Houses with < 5 people :", np.sum((account > 0) &
                                               (account < 5)))
# Out:
# Houses without people:  27
# Houses with people:  22876
# Houses with more than 5 people : 4497
# Houses with < 5 people : 15637

# %%
x
# Out:
# array([[5, 0, 3, 3],
#        [7, 9, 3, 5],
#        [2, 4, 7, 6]])

# %%
x<5
# Out:
# array([[False,  True,  True,  True],
#        [False, False,  True, False],
#        [ True,  True, False, False]])

# %%
#masking operation 
x[x<5]
# Out:
# array([0, 3, 3, 3, 2, 4])

# %%
account[account<5]
# Out:
# 0        3.0
# 7        1.0
# 8        3.0
# 9        3.0
# 11       3.0
#         ...
# 22889    4.0
# 22890    4.0
# 22892    2.0
# 22899    4.0
# 22900    2.0
# Name: household_size, Length: 15664, dtype: float64

# %%
houses=(account<5)

# %%
mucii=(account>5)

# %%
print("houses")
# Out:
# houses

# %%
plt.hist(account)
plt.ylabel("no of households ")
# Out:
# Text(0, 0.5, 'no of households ')

# %%
bank=df['Has a Bank account']
bank.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-52857ec9c1bc> in <module>
#       1 bank=df['Has a Bank account']
# ----> 2 bank.plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     259     def generate(self):
# ...

# %%
bin(42)

# %%
bin(42&56)

# %%
bin(10)

# %%
bool(42&569)

# %%
a=np.array([1,0,1,0,1,0],dtype=bool)
b=np.array([1,1,0,1,1,0],dtype=bool)

# %%
a|b

# %%
a or b

# %%
x=np.arange(10)
(x>4)&(x<8)

# %%
(x>4)and(x<8)

# %%
[account[1100],account[22000],account[15997]]

# %%
df[df['Respondent Age']<30]['Has a Bank account']

# %%
df.columns

# %%
df.index

# %%
df=pd.DataFrame(country,columns=['Type of Job'])

# %%
df.keys()

# %%
list(df.items())

# %%
df['Level of Education']='level of education'

# %%
df.columns

# %%
df.values

# %%
df.T

# %%
df.values[0]

# %%
data

# %%
np.nanmean(household_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-8b58f8396881> in <module>
# ----> 1 np.nanmean(household_size)
#
# NameError: name 'household_size' is not defined

# %%
df
# Out:
#           id country     year Has a Bank account Type of Location  \
# 0          0   Kenya  00:00.0                Yes            Rural
# 1          1   Kenya  00:00.0                 No            Rural
# 2          2   Kenya  00:00.0                Yes            Urban
# 3          3   Kenya  00:00.0                 No            Rural
# 4          4   Kenya  00:00.0                 No            Urban
# ...      ...     ...      ...                ...              ...
# 22898  23518  Uganda  00:00.0                 No            Rural
# 22899  23519  Uganda  00:00.0                 No            Rural
# 22900  23520  Uganda  00:00.0                 No            Rural
# 22901  23521  Uganda  00:00.0                 No            Rural
# 22902  23522  Uganda  00:00.0                 No            Urban
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0                   Yes             3.0            24.0               Female
# ...

# %%
mean=np.nanmean(df['household_size'])

# %%
min=np.nanmin(df['household_size'])
min
# Out:
# 0.0

# %%
max=np.max(df['household_size'])
max
# Out:
# 9.0

# %%
sum=np.sum(df['household_size'])
sum
# Out:
# 81745.0

# %%
import matplotlib.pyplot as plt
plt.plot(min,max)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df.isnull()
# Out:
#           id  country   year  Has a Bank account  Type of Location  \
# 0      False    False  False               False             False
# 1      False    False  False               False             False
# 2      False    False  False               False             False
# 3      False    False  False               False             False
# 4      False    False  False               False             False
# ...      ...      ...    ...                 ...               ...
# 22898  False    False  False               False             False
# 22899  False    False  False               False             False
# 22900  False    False  False               False             False
# 22901  False    False  False               False             False
# 22902  False    False  False               False             False
#
#        Cell Phone Access  household_size  Respondent Age  \
# 0                  False           False           False
# ...

# %%
df.notnull()
# Out:
#          id  country  year  Has a Bank account  Type of Location  \
# 0      True     True  True                True              True
# 1      True     True  True                True              True
# 2      True     True  True                True              True
# 3      True     True  True                True              True
# 4      True     True  True                True              True
# ...     ...      ...   ...                 ...               ...
# 22898  True     True  True                True              True
# 22899  True     True  True                True              True
# 22900  True     True  True                True              True
# 22901  True     True  True                True              True
# 22902  True     True  True                True              True
#
#        Cell Phone Access  household_size  Respondent Age  \
# 0                   True            True            True
# 1                   True            True            True
# ...

# %%
df.dropna()
# Out:
#           id country     year Has a Bank account Type of Location  \
# 0          0   Kenya  00:00.0                Yes            Rural
# 1          1   Kenya  00:00.0                 No            Rural
# 2          2   Kenya  00:00.0                Yes            Urban
# 3          3   Kenya  00:00.0                 No            Rural
# 4          4   Kenya  00:00.0                 No            Urban
# ...      ...     ...      ...                ...              ...
# 22892  23512  Uganda  00:00.0                 No            Rural
# 22899  23519  Uganda  00:00.0                 No            Rural
# 22900  23520  Uganda  00:00.0                 No            Rural
# 22901  23521  Uganda  00:00.0                 No            Rural
# 22902  23522  Uganda  00:00.0                 No            Urban
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0                   Yes             3.0            24.0               Female
# ...

# %%
22903-22725
# Out:
# 178

# %%
df[df['country'].isnull()]
# Out:
#           id country     year Has a Bank account Type of Location  \
# 17799  18200     NaN  00:00.0                 No            Urban
# 17800  18201     NaN  00:00.0                 No            Urban
# 17801  18202     NaN  00:00.0                 No            Urban
# 17802  18203     NaN  00:00.0                 No            Urban
# 17803  18204     NaN  00:00.0                 No            Urban
# 17804  18205     NaN  00:00.0                 No            Rural
# 17805  18206     NaN  00:00.0                 No            Urban
# 17806  18207     NaN  00:00.0                 No            Urban
# 17807  18208     NaN  00:00.0                 No            Urban
# 17911  18312     NaN  00:00.0                 No            Urban
# 17912  18313     NaN  00:00.0                 No            Urban
# 17913  18314     NaN  00:00.0                 No            Urban
# 17914  18315     NaN  00:00.0                 No            Rural
# ...

# %%
df['household_size'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22898     True
# 22899    False
# 22900    False
# 22901    False
# 22902    False
# Name: household_size, Length: 22903, dtype: bool

# %%
df1=df.dropna()

# %%
df1['Respondent Age'].max()
# Out:
# 83.0

# %%
df1['Respondent Age'].min()
# Out:
# 16.0

# %%
df1.shape
# Out:
# (22725, 13)

# %%
df1.size
# Out:
# 295425

# %%
df.shape
# Out:
# (22903, 13)

# %%
df1.loc['IQ Level']=np.nan
df1
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                id country     year Has a Bank account Type of Location  \
# 0             0.0   Kenya  00:00.0                Yes            Rural
# 1             1.0   Kenya  00:00.0                 No            Rural
# 2             2.0   Kenya  00:00.0                Yes            Urban
# 3             3.0   Kenya  00:00.0                 No            Rural
# 4             4.0   Kenya  00:00.0                 No            Urban
# ...           ...     ...      ...                ...              ...
# 22899     23519.0  Uganda  00:00.0                 No            Rural
# ...

# %%
df1.shape
# Out:
# (22726, 14)

# %%
df1
# Out:
#                id country     year Has a Bank account Type of Location  \
# 0             0.0   Kenya  00:00.0                Yes            Rural
# 1             1.0   Kenya  00:00.0                 No            Rural
# 2             2.0   Kenya  00:00.0                Yes            Urban
# 3             3.0   Kenya  00:00.0                 No            Rural
# 4             4.0   Kenya  00:00.0                 No            Urban
# ...           ...     ...      ...                ...              ...
# 22899     23519.0  Uganda  00:00.0                 No            Rural
# 22900     23520.0  Uganda  00:00.0                 No            Rural
# 22901     23521.0  Uganda  00:00.0                 No            Rural
# 22902     23522.0  Uganda  00:00.0                 No            Urban
# IQ Level     92.0      92       92                 92               92
#
#          Cell Phone Access  household_size  Respondent Age  \
# ...

# %%
df1.dropna()
# Out:
# Empty DataFrame
# Columns: [id, country, year, Has a Bank account, Type of Location, Cell Phone Access, household_size, Respondent Age, gender_of_respondent, The relathip with head, marital_status, Level of Education, Type of Job, IQ Level]
# Index: []

# %%
df1
# Out:
#                id country     year Has a Bank account Type of Location  \
# 0             0.0   Kenya  00:00.0                Yes            Rural
# 1             1.0   Kenya  00:00.0                 No            Rural
# 2             2.0   Kenya  00:00.0                Yes            Urban
# 3             3.0   Kenya  00:00.0                 No            Rural
# 4             4.0   Kenya  00:00.0                 No            Urban
# ...           ...     ...      ...                ...              ...
# 22899     23519.0  Uganda  00:00.0                 No            Rural
# 22900     23520.0  Uganda  00:00.0                 No            Rural
# 22901     23521.0  Uganda  00:00.0                 No            Rural
# 22902     23522.0  Uganda  00:00.0                 No            Urban
# IQ Level      NaN     NaN      NaN                NaN              NaN
#
#          Cell Phone Access  household_size  Respondent Age  \
# ...

# %%
df1.dropna(axis='columns',how='all')
# Out:
#                id country     year Has a Bank account Type of Location  \
# 0             0.0   Kenya  00:00.0                Yes            Rural
# 1             1.0   Kenya  00:00.0                 No            Rural
# 2             2.0   Kenya  00:00.0                Yes            Urban
# 3             3.0   Kenya  00:00.0                 No            Rural
# 4             4.0   Kenya  00:00.0                 No            Urban
# ...           ...     ...      ...                ...              ...
# 22899     23519.0  Uganda  00:00.0                 No            Rural
# 22900     23520.0  Uganda  00:00.0                 No            Rural
# 22901     23521.0  Uganda  00:00.0                 No            Rural
# 22902     23522.0  Uganda  00:00.0                 No            Urban
# IQ Level      NaN     NaN      NaN                NaN              NaN
#
#          Cell Phone Access  household_size  Respondent Age  \
# ...

# %%
df1.dropna(axis='rows',how='all')
# Out:
#             id country     year Has a Bank account Type of Location  \
# 0          0.0   Kenya  00:00.0                Yes            Rural
# 1          1.0   Kenya  00:00.0                 No            Rural
# 2          2.0   Kenya  00:00.0                Yes            Urban
# 3          3.0   Kenya  00:00.0                 No            Rural
# 4          4.0   Kenya  00:00.0                 No            Urban
# ...        ...     ...      ...                ...              ...
# 22892  23512.0  Uganda  00:00.0                 No            Rural
# 22899  23519.0  Uganda  00:00.0                 No            Rural
# 22900  23520.0  Uganda  00:00.0                 No            Rural
# 22901  23521.0  Uganda  00:00.0                 No            Rural
# 22902  23522.0  Uganda  00:00.0                 No            Urban
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# ...

# %%
df1
# Out:
#                id country     year Has a Bank account Type of Location  \
# 0             0.0   Kenya  00:00.0                Yes            Rural
# 1             1.0   Kenya  00:00.0                 No            Rural
# 2             2.0   Kenya  00:00.0                Yes            Urban
# 3             3.0   Kenya  00:00.0                 No            Rural
# 4             4.0   Kenya  00:00.0                 No            Urban
# ...           ...     ...      ...                ...              ...
# 22899     23519.0  Uganda  00:00.0                 No            Rural
# 22900     23520.0  Uganda  00:00.0                 No            Rural
# 22901     23521.0  Uganda  00:00.0                 No            Rural
# 22902     23522.0  Uganda  00:00.0                 No            Urban
# IQ Level      NaN     NaN      NaN                NaN              NaN
#
#          Cell Phone Access  household_size  Respondent Age  \
# ...

# %%
df1.dropna(axis='columns',how='all')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-a02f96426203> in <module>
# ----> 1 df1.dropna(axis='columns,rows',how='all')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4737             raise TypeError("supplying multiple axes to axis is no longer supported.")
#    4738
# -> 4739         axis = self._get_axis_number(axis)
#    4740         agg_axis = 1 - axis
#    4741
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     405             except KeyError:
#     406                 pass
# --> 407         raise ValueError(f"No axis named {axis} for object type {cls}")
#     408
#     409     @classmethod
#
# ValueError: No axis named columns,rows for object type <class 'pandas.core.frame.DataFrame'>

# %%
df1
# Out:
#                id country     year Has a Bank account Type of Location  \
# 0             0.0   Kenya  00:00.0                Yes            Rural
# 1             1.0   Kenya  00:00.0                 No            Rural
# 2             2.0   Kenya  00:00.0                Yes            Urban
# 3             3.0   Kenya  00:00.0                 No            Rural
# 4             4.0   Kenya  00:00.0                 No            Urban
# ...           ...     ...      ...                ...              ...
# 22899     23519.0  Uganda  00:00.0                 No            Rural
# 22900     23520.0  Uganda  00:00.0                 No            Rural
# 22901     23521.0  Uganda  00:00.0                 No            Rural
# 22902     23522.0  Uganda  00:00.0                 No            Urban
# IQ Level      NaN     NaN      NaN                NaN              NaN
#
#          Cell Phone Access  household_size  Respondent Age  \
# ...

# %%
df1_flat=df1.reset_index()
df1_flat
# Out:
#           index       id country     year Has a Bank account Type of Location  \
# 0             0      0.0   Kenya  00:00.0                Yes            Rural
# 1             1      1.0   Kenya  00:00.0                 No            Rural
# 2             2      2.0   Kenya  00:00.0                Yes            Urban
# 3             3      3.0   Kenya  00:00.0                 No            Rural
# 4             4      4.0   Kenya  00:00.0                 No            Urban
# ...         ...      ...     ...      ...                ...              ...
# 22721     22899  23519.0  Uganda  00:00.0                 No            Rural
# 22722     22900  23520.0  Uganda  00:00.0                 No            Rural
# 22723     22901  23521.0  Uganda  00:00.0                 No            Rural
# 22724     22902  23522.0  Uganda  00:00.0                 No            Urban
# 22725  IQ Level      NaN     NaN      NaN                NaN              NaN
#
# ...

# %%
df1.fillna(0)
# Out:
#                id country     year Has a Bank account Type of Location  \
# 0             0.0   Kenya  00:00.0                Yes            Rural
# 1             1.0   Kenya  00:00.0                 No            Rural
# 2             2.0   Kenya  00:00.0                Yes            Urban
# 3             3.0   Kenya  00:00.0                 No            Rural
# 4             4.0   Kenya  00:00.0                 No            Urban
# ...           ...     ...      ...                ...              ...
# 22899     23519.0  Uganda  00:00.0                 No            Rural
# 22900     23520.0  Uganda  00:00.0                 No            Rural
# 22901     23521.0  Uganda  00:00.0                 No            Rural
# 22902     23522.0  Uganda  00:00.0                 No            Urban
# IQ Level      0.0       0        0                  0                0
#
#          Cell Phone Access  household_size  Respondent Age  \
# ...

# %%
df1.unstack()
# Out:
# id        0             0
#           1             1
#           2             2
#           3             3
#           4             4
#                      ...
# IQ Level  22899       NaN
#           22900       NaN
#           22901       NaN
#           22902       NaN
#           IQ Level    NaN
# Length: 318164, dtype: object

# %%
df1.stack()
# Out:
# 0      id                                          0
#        country                                 Kenya
#        year                                  00:00.0
#        Has a Bank account                        Yes
#        Type of Location                        Rural
#                                         ...
# 22902  gender_of_respondent                   Female
#        The relathip with head                 Parent
#        marital_status             Divorced/Seperated
#        Level of Education        Secondary education
#        Type of Job                     Self employed
# Length: 295425, dtype: object

# %%
df1=df1.drop('IQ Level')

# %%
df1=df1.set_index('id ')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-f9f001b9c72e> in <module>
# ----> 1 df1=df1.set_index('id ')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['id '] are in the columns"

# %%
df1
# Out:
#             id country     year Has a Bank account Type of Location  \
# 0          0.0   Kenya  00:00.0                Yes            Rural
# 1          1.0   Kenya  00:00.0                 No            Rural
# 2          2.0   Kenya  00:00.0                Yes            Urban
# 3          3.0   Kenya  00:00.0                 No            Rural
# 4          4.0   Kenya  00:00.0                 No            Urban
# ...        ...     ...      ...                ...              ...
# 22892  23512.0  Uganda  00:00.0                 No            Rural
# 22899  23519.0  Uganda  00:00.0                 No            Rural
# 22900  23520.0  Uganda  00:00.0                 No            Rural
# 22901  23521.0  Uganda  00:00.0                 No            Rural
# 22902  23522.0  Uganda  00:00.0                 No            Urban
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# ...
